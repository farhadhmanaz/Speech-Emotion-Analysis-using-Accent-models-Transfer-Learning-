# %% [markdown]
# # Mounting drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Importing libraries

# %%
import csv    
import os
import audioread
import pandas as pd
import numpy as np
import librosa
from tqdm import tqdm
import math
import librosa,librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import tensorflow as tf
from sklearn.externals import joblib
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# # Defining Functions

# %%
# Getting featues of the audio file
    
def features(file_name):
    audio,sample_rate=librosa.load(file_name,res_type='kaiser_fast')
    mfccs=librosa.feature.mfcc(audio,sr=22050,n_fft=2048,hop_length=512,n_mfcc=13)
    scaled_mfccs=np.mean(mfccs.T,axis=0)
    return scaled_mfccs

# reading all the datas from folder and extracting features

def readDataAccent(dataset_path,csv_file):
    metasa=pd.read_csv(csv_file)
    metasa.head()
    x_features=[]
    for i,row in metasa.iterrows():
    
        file_name=os.path.join(os.path.abspath(dataset_path),str(row["class"])+"/",str(row["filename"]))
        class_name=row["class"]
        data=features(file_name)
        x_features.append([data,class_name])
    return x_features



# Spliting values for test and train

def SplitValues(ex_features):
    data_frame=pd.DataFrame(ex_features,columns=['feature','class'])
    
    feature=np.array(data_frame['feature'].tolist())
    classes=np.array(data_frame['class'].tolist())
    classes=np.asarray(pd.get_dummies(classes))
    
    x_train,x_test,y_train,y_test = train_test_split(feature,classes,test_size=0.25)
    x_train,x_valid,y_train,y_valid = train_test_split(feature,classes,test_size=0.20)
   
    x_train =x_train[...,np.newaxis]
    x_valid =x_valid[...,np.newaxis]
    x_test =x_test[...,np.newaxis]
    input_shape=(x_train.shape[1],x_train.shape[2])
    
    return x_train,x_valid, x_test, y_train, y_valid, y_test, input_shape


# Model creation for Accent Classification

def createModelA(input_shape):
    #model creation
    model=keras.Sequential()

    #convo layer 1
    model.add(keras.layers.Conv1D(32,3,activation='relu',padding='same',input_shape=input_shape,name="layer_1c"))
    model.add(keras.layers.MaxPool1D(3, strides=2,padding='same' , name="layer_1m"))
    model.add(keras.layers.BatchNormalization(name="layer_1bn"))

    #convo layer 2
    model.add(keras.layers.Conv1D(32,3,padding='same',activation='relu', name="layer_2c"))
    model.add(keras.layers.MaxPool1D(3, strides=2,padding='same' , name="layer_2m"))
    model.add(keras.layers.BatchNormalization(name="layer_2bn"))

    #convo layer 3
    model.add(keras.layers.Conv1D(32,3,padding='same',activation='relu', name="layer_3c"))
    model.add(keras.layers.MaxPool1D(3, strides=2,padding='same', name="layer_3m"))
    model.add(keras.layers.BatchNormalization(name="layer_3bn"))

    #convo layer 4
    model.add(keras.layers.Conv1D(32,3,padding='same',activation='relu', name="layer_4c"))
    model.add(keras.layers.MaxPool1D(3, strides=2,padding='same', name="layer_4m"))
    model.add(keras.layers.BatchNormalization(name="layer_4bn"))

    #convo layer 5
    model.add(keras.layers.Conv1D(32,3,padding='same',activation='relu', name="layer_5c"))
    model.add(keras.layers.MaxPool1D(2, strides=2,padding='same', name="layer_5m"))
    model.add(keras.layers.BatchNormalization(name="layer_5bn"))

    #flatten the output layer and add some dense layer

    model.add(keras.layers.Flatten(name="layer_fl"))
    model.add(keras.layers.Dense(256,activation='relu',name="layer_d1"))
    model.add(keras.layers.Dense(128,activation='relu',name="layer_d2"))
    model.add(keras.layers.Dense(64,activation='relu',name="layer_d3"))
    model.add(keras.layers.Dropout(0.3))

    #output layer

    model.add(keras.layers.Dense(3,activation='softmax'))
    
    optimizer=keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,loss="categorical_crossentropy",metrics=["accuracy"])
    
    print("model created sucessfully")
    
    return model


# Getting Accuracy of the model

def testModelAccuracy(model,x_test,y_test):
    test_error,test_accuracy=model.evaluate(x_test,y_test,verbose=0)
    print()
    print("Accuracy on test is: {}".format(test_accuracy))
    print()

    
# plotting Accuracy and error

def PlotAccuracy(history):
    fig,axes = plt.subplots(2)

    axes[0].plot(history.history["accuracy"],label="train_accuracy")
    axes[0].plot(history.history["val_accuracy"],label="test_accuracy")
    axes[0].set_ylabel("Accuracy")
    axes[0].legend(loc="lower right")
    axes[0].set_ylabel("Accuracy eval")

    axes[1].plot(history.history["loss"],label="train_error")
    axes[1].plot(history.history["val_loss"],label="test_error")
    axes[1].set_ylabel("error")
    axes[1].set_ylabel("epoch")
    axes[1].legend(loc="upper right")
    axes[1].set_ylabel("error eval")

    plt.show()


print("All function defined")

print()
# Out:
# All function defined

# %% [markdown]
# # Reading audio files and Extracting features

# %%
# parameters ---------> (folder_name , csvfile_name)

ex_features_model_Accent = readDataAccent("/content/drive/MyDrive/Speech_Emotion_Analysis_TL/dataset" , "/content/drive/MyDrive/Speech_Emotion_Analysis_TL/dataset.csv")
print("Operation done")
# Out:
# Operation done

# %% [markdown]
# # Spliting values for train and test

# %%
model_Accent_xtrain,model_Accent_xvalid, model_Accent_xtest,model_Accent_ytrain,model_Accent_yvalid, model_Accent_ytest, input_shape_model_Accent = SplitValues(ex_features_model_Accent)

# %% [markdown]
# # Creating Model

# %%
model_Accent=createModelA(input_shape_model_Accent)
model_Accent.summary()
# Out:
# model created sucessfully
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1c (Conv1D)            (None, 13, 32)            128
# _________________________________________________________________
# layer_1m (MaxPooling1D)      (None, 7, 32)             0
# _________________________________________________________________
# layer_1bn (BatchNormalizatio (None, 7, 32)             128
# _________________________________________________________________
# layer_2c (Conv1D)            (None, 7, 32)             3104
# _________________________________________________________________
# layer_2m (MaxPooling1D)      (None, 4, 32)             0
# _________________________________________________________________
# layer_2bn (BatchNormalizatio (None, 4, 32)             128
# _________________________________________________________________
# layer_3c (Conv1D)            (None, 4, 32)             3104
# _________________________________________________________________
# layer_3m (MaxPooling1D)      (None, 2, 32)             0
# _________________________________________________________________
# layer_3bn (BatchNormalizatio (None, 2, 32)             128
# _________________________________________________________________
# layer_4c (Conv1D)            (None, 2, 32)             3104
# _________________________________________________________________
# layer_4m (MaxPooling1D)      (None, 1, 32)             0
# _________________________________________________________________
# layer_4bn (BatchNormalizatio (None, 1, 32)             128
# _________________________________________________________________
# layer_5c (Conv1D)            (None, 1, 32)             3104
# _________________________________________________________________
# layer_5m (MaxPooling1D)      (None, 1, 32)             0
# _________________________________________________________________
# layer_5bn (BatchNormalizatio (None, 1, 32)             128
# _________________________________________________________________
# layer_fl (Flatten)           (None, 32)                0
# _________________________________________________________________
# layer_d1 (Dense)             (None, 256)               8448
# _________________________________________________________________
# layer_d2 (Dense)             (None, 128)               32896
# _________________________________________________________________
# layer_d3 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 195
# =================================================================
# Total params: 62,979
# Trainable params: 62,659
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# # Training network

# %%
history_model_Accent = model_Accent.fit(model_Accent_xtrain,model_Accent_ytrain,validation_data=(model_Accent_xvalid, model_Accent_yvalid),verbose=1,epochs=150,batch_size=32)
# Out:
# Epoch 1/150
# 43/43 [==============================] - 3s 16ms/step - loss: 1.0578 - accuracy: 0.4329 - val_loss: 1.0979 - val_accuracy: 0.3178
# Epoch 2/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.9737 - accuracy: 0.5408 - val_loss: 1.0922 - val_accuracy: 0.4694
# Epoch 3/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.8998 - accuracy: 0.5758 - val_loss: 1.0738 - val_accuracy: 0.4344
# Epoch 4/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.8427 - accuracy: 0.5999 - val_loss: 1.0405 - val_accuracy: 0.4781
# Epoch 5/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7981 - accuracy: 0.6414 - val_loss: 0.9923 - val_accuracy: 0.4898
# Epoch 6/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7519 - accuracy: 0.6531 - val_loss: 0.9481 - val_accuracy: 0.5248
# Epoch 7/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7280 - accuracy: 0.6676 - val_loss: 0.8871 - val_accuracy: 0.5685
# Epoch 8/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7032 - accuracy: 0.6837 - val_loss: 0.8082 - val_accuracy: 0.6006
# Epoch 9/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.6890 - accuracy: 0.6844 - val_loss: 0.7657 - val_accuracy: 0.6443
# Epoch 10/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.6655 - accuracy: 0.7106 - val_loss: 0.7309 - val_accuracy: 0.6647
# Epoch 11/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.6131 - accuracy: 0.7223 - val_loss: 0.6938 - val_accuracy: 0.6910
# Epoch 12/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5993 - accuracy: 0.7347 - val_loss: 0.6563 - val_accuracy: 0.7289
# Epoch 13/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.6215 - accuracy: 0.7245 - val_loss: 0.6736 - val_accuracy: 0.7114
# Epoch 14/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5860 - accuracy: 0.7405 - val_loss: 0.7190 - val_accuracy: 0.6735
# Epoch 15/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5650 - accuracy: 0.7529 - val_loss: 0.6909 - val_accuracy: 0.6939
# Epoch 16/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5864 - accuracy: 0.7362 - val_loss: 0.7061 - val_accuracy: 0.6647
# Epoch 17/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.5418 - accuracy: 0.7609 - val_loss: 0.6972 - val_accuracy: 0.6968
# Epoch 18/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5519 - accuracy: 0.7653 - val_loss: 0.5897 - val_accuracy: 0.7347
# Epoch 19/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5252 - accuracy: 0.7886 - val_loss: 0.5918 - val_accuracy: 0.7755
# Epoch 20/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5203 - accuracy: 0.7828 - val_loss: 0.5991 - val_accuracy: 0.7289
# Epoch 21/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5068 - accuracy: 0.7770 - val_loss: 0.6089 - val_accuracy: 0.7638
# Epoch 22/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4875 - accuracy: 0.7952 - val_loss: 0.5917 - val_accuracy: 0.7609
# Epoch 23/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4760 - accuracy: 0.7966 - val_loss: 0.5935 - val_accuracy: 0.7522
# Epoch 24/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5054 - accuracy: 0.7857 - val_loss: 0.5739 - val_accuracy: 0.7843
# Epoch 25/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4753 - accuracy: 0.8032 - val_loss: 0.5548 - val_accuracy: 0.7784
# Epoch 26/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4839 - accuracy: 0.7901 - val_loss: 0.6844 - val_accuracy: 0.7114
# Epoch 27/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4635 - accuracy: 0.8098 - val_loss: 0.5591 - val_accuracy: 0.7726
# Epoch 28/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4576 - accuracy: 0.8149 - val_loss: 0.6817 - val_accuracy: 0.7230
# Epoch 29/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4514 - accuracy: 0.8134 - val_loss: 0.5742 - val_accuracy: 0.7609
# Epoch 30/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4480 - accuracy: 0.8054 - val_loss: 0.5889 - val_accuracy: 0.7668
# Epoch 31/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4385 - accuracy: 0.8222 - val_loss: 0.5492 - val_accuracy: 0.7755
# Epoch 32/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.4404 - accuracy: 0.8185 - val_loss: 0.5767 - val_accuracy: 0.7726
# Epoch 33/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.4328 - accuracy: 0.8229 - val_loss: 0.6058 - val_accuracy: 0.7347
# Epoch 34/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.4141 - accuracy: 0.8273 - val_loss: 0.5957 - val_accuracy: 0.7580
# Epoch 35/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4100 - accuracy: 0.8353 - val_loss: 0.6348 - val_accuracy: 0.7259
# Epoch 36/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4225 - accuracy: 0.8222 - val_loss: 0.6616 - val_accuracy: 0.7289
# Epoch 37/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.4009 - accuracy: 0.8382 - val_loss: 0.5695 - val_accuracy: 0.7668
# Epoch 38/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4202 - accuracy: 0.8229 - val_loss: 0.6069 - val_accuracy: 0.7434
# Epoch 39/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3877 - accuracy: 0.8367 - val_loss: 0.5883 - val_accuracy: 0.7668
# Epoch 40/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3892 - accuracy: 0.8477 - val_loss: 0.5534 - val_accuracy: 0.7843
# Epoch 41/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3853 - accuracy: 0.8477 - val_loss: 0.5757 - val_accuracy: 0.7697
# Epoch 42/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4049 - accuracy: 0.8316 - val_loss: 0.5488 - val_accuracy: 0.7755
# Epoch 43/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3768 - accuracy: 0.8448 - val_loss: 0.5826 - val_accuracy: 0.7726
# Epoch 44/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3997 - accuracy: 0.8309 - val_loss: 0.5888 - val_accuracy: 0.7638
# Epoch 45/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3760 - accuracy: 0.8499 - val_loss: 0.5548 - val_accuracy: 0.7784
# Epoch 46/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.3794 - accuracy: 0.8506 - val_loss: 0.6250 - val_accuracy: 0.7638
# Epoch 47/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3768 - accuracy: 0.8426 - val_loss: 0.5807 - val_accuracy: 0.7580
# Epoch 48/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3743 - accuracy: 0.8440 - val_loss: 0.5745 - val_accuracy: 0.7697
# Epoch 49/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3659 - accuracy: 0.8440 - val_loss: 0.5686 - val_accuracy: 0.7609
# Epoch 50/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.3807 - accuracy: 0.8411 - val_loss: 0.5387 - val_accuracy: 0.7901
# Epoch 51/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3532 - accuracy: 0.8571 - val_loss: 0.5414 - val_accuracy: 0.7755
# Epoch 52/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3576 - accuracy: 0.8688 - val_loss: 0.5516 - val_accuracy: 0.7813
# Epoch 53/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3354 - accuracy: 0.8673 - val_loss: 0.5625 - val_accuracy: 0.7697
# Epoch 54/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.3343 - accuracy: 0.8681 - val_loss: 0.5416 - val_accuracy: 0.7755
# Epoch 55/150
# 43/43 [==============================] - 0s 9ms/step - loss: 0.3402 - accuracy: 0.8681 - val_loss: 0.6059 - val_accuracy: 0.7464
# Epoch 56/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3510 - accuracy: 0.8608 - val_loss: 0.6235 - val_accuracy: 0.7609
# Epoch 57/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.3404 - accuracy: 0.8615 - val_loss: 0.5894 - val_accuracy: 0.7522
# Epoch 58/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.3392 - accuracy: 0.8608 - val_loss: 0.6016 - val_accuracy: 0.7609
# Epoch 59/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3320 - accuracy: 0.8695 - val_loss: 0.6800 - val_accuracy: 0.7464
# Epoch 60/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3295 - accuracy: 0.8652 - val_loss: 0.6170 - val_accuracy: 0.7551
# Epoch 61/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3320 - accuracy: 0.8703 - val_loss: 0.8169 - val_accuracy: 0.6735
# Epoch 62/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.3250 - accuracy: 0.8724 - val_loss: 0.6559 - val_accuracy: 0.7726
# Epoch 63/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2934 - accuracy: 0.8776 - val_loss: 0.5986 - val_accuracy: 0.7580
# Epoch 64/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2923 - accuracy: 0.8827 - val_loss: 0.6150 - val_accuracy: 0.7551
# Epoch 65/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2979 - accuracy: 0.8827 - val_loss: 0.6610 - val_accuracy: 0.7493
# Epoch 66/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2921 - accuracy: 0.8776 - val_loss: 0.6855 - val_accuracy: 0.7347
# Epoch 67/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3050 - accuracy: 0.8768 - val_loss: 0.6268 - val_accuracy: 0.7493
# Epoch 68/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.3113 - accuracy: 0.8834 - val_loss: 0.7087 - val_accuracy: 0.7376
# Epoch 69/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.3080 - accuracy: 0.8863 - val_loss: 0.6709 - val_accuracy: 0.7434
# Epoch 70/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2824 - accuracy: 0.8892 - val_loss: 0.6481 - val_accuracy: 0.7609
# Epoch 71/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2721 - accuracy: 0.8848 - val_loss: 0.6388 - val_accuracy: 0.7551
# Epoch 72/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2950 - accuracy: 0.8841 - val_loss: 0.6639 - val_accuracy: 0.7464
# Epoch 73/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2841 - accuracy: 0.8870 - val_loss: 0.5990 - val_accuracy: 0.7697
# Epoch 74/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2719 - accuracy: 0.8899 - val_loss: 0.6259 - val_accuracy: 0.7668
# Epoch 75/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2927 - accuracy: 0.8914 - val_loss: 0.6286 - val_accuracy: 0.7434
# Epoch 76/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2878 - accuracy: 0.8834 - val_loss: 0.6049 - val_accuracy: 0.7726
# Epoch 77/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2723 - accuracy: 0.8899 - val_loss: 0.6119 - val_accuracy: 0.7726
# Epoch 78/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2639 - accuracy: 0.8972 - val_loss: 0.6099 - val_accuracy: 0.7697
# Epoch 79/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2523 - accuracy: 0.8987 - val_loss: 0.6235 - val_accuracy: 0.7668
# Epoch 80/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2557 - accuracy: 0.9001 - val_loss: 0.6725 - val_accuracy: 0.7551
# Epoch 81/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2492 - accuracy: 0.9118 - val_loss: 0.6786 - val_accuracy: 0.7464
# Epoch 82/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2601 - accuracy: 0.9103 - val_loss: 0.6304 - val_accuracy: 0.7813
# Epoch 83/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2597 - accuracy: 0.8921 - val_loss: 0.6151 - val_accuracy: 0.7697
# Epoch 84/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2322 - accuracy: 0.9103 - val_loss: 0.6059 - val_accuracy: 0.7726
# Epoch 85/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2312 - accuracy: 0.9052 - val_loss: 0.6936 - val_accuracy: 0.7609
# Epoch 86/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2742 - accuracy: 0.8921 - val_loss: 0.7058 - val_accuracy: 0.7522
# Epoch 87/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2271 - accuracy: 0.9140 - val_loss: 0.6195 - val_accuracy: 0.7493
# Epoch 88/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2456 - accuracy: 0.9052 - val_loss: 0.6589 - val_accuracy: 0.7551
# Epoch 89/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2366 - accuracy: 0.9082 - val_loss: 0.7175 - val_accuracy: 0.7580
# Epoch 90/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2480 - accuracy: 0.9052 - val_loss: 0.6428 - val_accuracy: 0.7813
# Epoch 91/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2437 - accuracy: 0.9031 - val_loss: 0.6444 - val_accuracy: 0.7784
# Epoch 92/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2298 - accuracy: 0.9096 - val_loss: 0.6669 - val_accuracy: 0.7843
# Epoch 93/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2214 - accuracy: 0.9176 - val_loss: 0.6494 - val_accuracy: 0.7784
# Epoch 94/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2354 - accuracy: 0.9133 - val_loss: 0.6176 - val_accuracy: 0.7872
# Epoch 95/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2516 - accuracy: 0.9023 - val_loss: 0.6732 - val_accuracy: 0.7784
# Epoch 96/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2146 - accuracy: 0.9227 - val_loss: 0.7080 - val_accuracy: 0.7609
# Epoch 97/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2285 - accuracy: 0.9133 - val_loss: 0.7158 - val_accuracy: 0.7609
# Epoch 98/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2229 - accuracy: 0.9147 - val_loss: 0.7998 - val_accuracy: 0.7609
# Epoch 99/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2202 - accuracy: 0.9176 - val_loss: 0.7072 - val_accuracy: 0.7784
# Epoch 100/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2363 - accuracy: 0.9133 - val_loss: 0.6889 - val_accuracy: 0.7697
# Epoch 101/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2127 - accuracy: 0.9176 - val_loss: 0.6118 - val_accuracy: 0.7843
# Epoch 102/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2042 - accuracy: 0.9257 - val_loss: 0.6650 - val_accuracy: 0.7930
# Epoch 103/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.1939 - accuracy: 0.9264 - val_loss: 0.7192 - val_accuracy: 0.7638
# Epoch 104/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2088 - accuracy: 0.9198 - val_loss: 0.7339 - val_accuracy: 0.7638
# Epoch 105/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2010 - accuracy: 0.9206 - val_loss: 0.6891 - val_accuracy: 0.7697
# Epoch 106/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2077 - accuracy: 0.9191 - val_loss: 0.7049 - val_accuracy: 0.7638
# Epoch 107/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2178 - accuracy: 0.9162 - val_loss: 0.7535 - val_accuracy: 0.7551
# Epoch 108/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2150 - accuracy: 0.9118 - val_loss: 0.6914 - val_accuracy: 0.7668
# Epoch 109/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2043 - accuracy: 0.9264 - val_loss: 0.6731 - val_accuracy: 0.7697
# Epoch 110/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2339 - accuracy: 0.9052 - val_loss: 0.6931 - val_accuracy: 0.7697
# Epoch 111/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2226 - accuracy: 0.9082 - val_loss: 0.7325 - val_accuracy: 0.7551
# Epoch 112/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2042 - accuracy: 0.9213 - val_loss: 0.7157 - val_accuracy: 0.7668
# Epoch 113/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2044 - accuracy: 0.9162 - val_loss: 0.7005 - val_accuracy: 0.7813
# Epoch 114/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.1994 - accuracy: 0.9227 - val_loss: 0.7761 - val_accuracy: 0.7668
# Epoch 115/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.1925 - accuracy: 0.9220 - val_loss: 0.6691 - val_accuracy: 0.7784
# Epoch 116/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1970 - accuracy: 0.9257 - val_loss: 0.7021 - val_accuracy: 0.7668
# Epoch 117/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1899 - accuracy: 0.9322 - val_loss: 0.7355 - val_accuracy: 0.7697
# Epoch 118/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1865 - accuracy: 0.9300 - val_loss: 0.7127 - val_accuracy: 0.7697
# Epoch 119/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2225 - accuracy: 0.9220 - val_loss: 0.7188 - val_accuracy: 0.7609
# Epoch 120/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1975 - accuracy: 0.9176 - val_loss: 0.6301 - val_accuracy: 0.7872
# Epoch 121/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1856 - accuracy: 0.9322 - val_loss: 0.6991 - val_accuracy: 0.7580
# Epoch 122/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1616 - accuracy: 0.9315 - val_loss: 0.6748 - val_accuracy: 0.7726
# Epoch 123/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.1765 - accuracy: 0.9329 - val_loss: 0.7397 - val_accuracy: 0.7493
# Epoch 124/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1693 - accuracy: 0.9410 - val_loss: 0.7188 - val_accuracy: 0.7813
# Epoch 125/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1851 - accuracy: 0.9300 - val_loss: 0.7357 - val_accuracy: 0.7638
# Epoch 126/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.1892 - accuracy: 0.9271 - val_loss: 0.7901 - val_accuracy: 0.7726
# Epoch 127/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.2169 - accuracy: 0.9147 - val_loss: 0.8827 - val_accuracy: 0.7522
# Epoch 128/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.2027 - accuracy: 0.9169 - val_loss: 0.6969 - val_accuracy: 0.7638
# Epoch 129/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.1985 - accuracy: 0.9213 - val_loss: 0.6998 - val_accuracy: 0.7843
# Epoch 130/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1575 - accuracy: 0.9453 - val_loss: 0.7527 - val_accuracy: 0.7784
# Epoch 131/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.1694 - accuracy: 0.9366 - val_loss: 0.7962 - val_accuracy: 0.7697
# Epoch 132/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1773 - accuracy: 0.9278 - val_loss: 0.7684 - val_accuracy: 0.7638
# Epoch 133/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1609 - accuracy: 0.9453 - val_loss: 0.7401 - val_accuracy: 0.7609
# Epoch 134/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1472 - accuracy: 0.9410 - val_loss: 0.7582 - val_accuracy: 0.7522
# Epoch 135/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.1509 - accuracy: 0.9453 - val_loss: 0.7039 - val_accuracy: 0.7697
# Epoch 136/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1658 - accuracy: 0.9410 - val_loss: 0.7850 - val_accuracy: 0.7755
# Epoch 137/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1760 - accuracy: 0.9380 - val_loss: 0.7365 - val_accuracy: 0.7668
# Epoch 138/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1363 - accuracy: 0.9490 - val_loss: 0.7542 - val_accuracy: 0.7726
# Epoch 139/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1766 - accuracy: 0.9293 - val_loss: 0.8115 - val_accuracy: 0.7668
# Epoch 140/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1969 - accuracy: 0.9235 - val_loss: 0.7211 - val_accuracy: 0.7784
# Epoch 141/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1466 - accuracy: 0.9497 - val_loss: 0.7551 - val_accuracy: 0.7638
# Epoch 142/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1868 - accuracy: 0.9286 - val_loss: 0.7725 - val_accuracy: 0.7609
# Epoch 143/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1585 - accuracy: 0.9337 - val_loss: 0.7440 - val_accuracy: 0.7493
# Epoch 144/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1768 - accuracy: 0.9329 - val_loss: 0.8753 - val_accuracy: 0.7609
# Epoch 145/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.1625 - accuracy: 0.9351 - val_loss: 0.7578 - val_accuracy: 0.7493
# Epoch 146/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.1755 - accuracy: 0.9337 - val_loss: 0.7347 - val_accuracy: 0.7609
# Epoch 147/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1538 - accuracy: 0.9373 - val_loss: 0.7358 - val_accuracy: 0.7930
# Epoch 148/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1360 - accuracy: 0.9504 - val_loss: 0.8415 - val_accuracy: 0.7726
# Epoch 149/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.1521 - accuracy: 0.9395 - val_loss: 0.7867 - val_accuracy: 0.7522
# Epoch 150/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.1787 - accuracy: 0.9264 - val_loss: 0.7731 - val_accuracy: 0.7697

# %% [markdown]
# # Testing and saving network

# %%
testModelAccuracy(model_Accent,model_Accent_xtest,model_Accent_ytest)
PlotAccuracy(history_model_Accent)

model_Accent.save_weights('/content/drive/MyDrive/Speech_Emotion_Analysis_TL/weights/Accentweights.h5')

model_Accent.save("/content/drive/MyDrive/Speech_Emotion_Analysis_TL/savedModels/savedModelAccent.h5")
# Out:
# Accuracy on test is: 0.9114218950271606
