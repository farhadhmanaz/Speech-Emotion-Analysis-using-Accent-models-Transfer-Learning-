# %% [markdown]
# #Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Importing Libraries

# %%
import csv    
import os
import audioread
import pandas as pd
import numpy as np
import librosa
from tqdm import tqdm
import math
import librosa,librosa.display
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import tensorflow as tf
from sklearn.externals import joblib
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# #Defining functions

# %%
# Getting featues of the audio file
    
def features(file_name):
    audio,sample_rate=librosa.load(file_name,res_type='kaiser_fast')
    mfccs=librosa.feature.mfcc(audio,sr=22050,n_fft=2048,hop_length=512,n_mfcc=13)
    scaled_mfccs=np.mean(mfccs.T,axis=0)
    return scaled_mfccs

# reading all the datas from folder and extracting features

def readDataAccent(dataset_path,csv_file):
    metasa=pd.read_csv(csv_file)
    metasa.head()
    x_features=[]
    for i,row in metasa.iterrows():
    
        file_name=os.path.join(os.path.abspath(dataset_path),str(row["class"])+"/",str(row["filename"]))
        class_name=row["class"]
        data=features(file_name)
        x_features.append([data,class_name])
    return x_features



# Spliting values for test and train

def SplitValues(ex_features):
    data_frame=pd.DataFrame(ex_features,columns=['feature','class'])
    
    feature=np.array(data_frame['feature'].tolist())
    classes=np.array(data_frame['class'].tolist())
    classes=np.asarray(pd.get_dummies(classes))
    
    x_train,x_test,y_train,y_test = train_test_split(feature,classes,test_size=0.25)  
    x_train,x_valid,y_train,y_valid = train_test_split(feature,classes,test_size=0.20)
   
    x_train =x_train[...,np.newaxis]
    x_valid =x_valid[...,np.newaxis]
    x_test =x_test[...,np.newaxis]

    input_shape=(x_train.shape[1],x_train.shape[2])
    
    return x_train,x_valid, x_test, y_train, y_valid, y_test, input_shape


def readDataEmotion(dataset_path,csv_file):
    metasa=pd.read_csv(csv_file)
    metasa.head()
    x_features=[]
    for i,row in metasa.iterrows():
    
        file_name=os.path.join(os.path.abspath(dataset_path),str(row["class"])+"/",str(row["filename"]))
        emotion=str(row["emotion"])
        data=features(file_name)
        x_features.append([data,emotion])
    return x_features



def createModelEmotion(input_shape):
     #model creation
    model=keras.Sequential()

    #convo layer 1
    model.add(keras.layers.Conv1D(32,3,activation='relu',padding='same',input_shape=input_shape,name="layer_1c"))
    model.add(keras.layers.MaxPool1D(3, strides=2,padding='same' , name="layer_1m"))
    model.add(keras.layers.BatchNormalization(name="layer_1bn"))

    #convo layer 2
    model.add(keras.layers.Conv1D(32,3,padding='same',activation='relu', name="layer_2c"))
    model.add(keras.layers.MaxPool1D(3, strides=2,padding='same' , name="layer_2m"))
    model.add(keras.layers.BatchNormalization(name="layer_2bn"))

    #convo layer 3
    model.add(keras.layers.Conv1D(32,3,padding='same',activation='relu', name="layer_3c"))
    model.add(keras.layers.MaxPool1D(3, strides=2,padding='same', name="layer_3m"))
    model.add(keras.layers.BatchNormalization(name="layer_3bn"))

    #convo layer 4
    model.add(keras.layers.Conv1D(32,3,padding='same',activation='relu', name="layer_4c"))
    model.add(keras.layers.MaxPool1D(3, strides=2,padding='same', name="layer_4m"))
    model.add(keras.layers.BatchNormalization(name="layer_4bn"))

    #convo layer 5
    model.add(keras.layers.Conv1D(32,3,padding='same',activation='relu', name="layer_5c"))
    model.add(keras.layers.MaxPool1D(2, strides=2,padding='same', name="layer_5m"))
    model.add(keras.layers.BatchNormalization(name="layer_5bn"))

    #flatten the output layer and add some dense layer

    model.add(keras.layers.Flatten(name="layer_fl"))
    model.add(keras.layers.Dense(256,activation='relu',name="layer_d1"))
    model.add(keras.layers.Dense(128,activation='relu',name="layer_d2"))
    model.add(keras.layers.Dense(64,activation='relu',name="layer_d3"))
    model.add(keras.layers.Dropout(0.3))

    
    
    optimizer=keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,loss="categorical_crossentropy",metrics=["accuracy"])
    
    print("model created sucessfully")
    
    return model



# Getting Accuracy of the model

def testModelAccuracy(model,x_test,y_test):
    test_error,test_accuracy=model.evaluate(x_test,y_test,verbose=0)
    print()
    print("Accuracy on test is: {}".format(test_accuracy))
    print()
    print("Error on test is: {}".format(test_error))
    print()

    
# plotting Accuracy and error

def PlotAccuracy(history):
    fig,axes = plt.subplots(2)

    axes[0].plot(history.history["accuracy"],label="train_accuracy")
    axes[0].plot(history.history["val_accuracy"],label="test_accuracy")
    axes[0].set_ylabel("Accuracy")
    axes[0].legend(loc="lower right")
    axes[0].set_ylabel("Accuracy eval")

    axes[1].plot(history.history["loss"],label="train_error")
    axes[1].plot(history.history["val_loss"],label="test_error")
    axes[1].set_ylabel("error")
    axes[1].set_ylabel("epoch")
    axes[1].legend(loc="upper right")
    axes[1].set_ylabel("error eval")

    plt.show()

# %% [markdown]
# #Reading audio files and Extracting features

# %%
# parameters ---------> (folder_name , csvfile_name)
ex_features_model_Emotion = readDataEmotion("/content/drive/MyDrive/Speech_Emotion_Analysis_TL/dataset" , "/content/drive/MyDrive/Speech_Emotion_Analysis_TL/dataset.csv")
print("Operation done")
# Out:
# Operation done

# %% [markdown]
# #Spliting values

# %%
model_Emotion_xtrain,model_Emotion_xvalid, model_Emotion_xtest,model_Emotion_ytrain,model_Emotion_yvalid, model_Emotion_ytest,input_shape_model_Emotion = SplitValues(ex_features_model_Emotion)

# %% [markdown]
# #Model creation

# %%
Model_Emotion=createModelEmotion(input_shape_model_Emotion)
Model_Emotion.summary()
# Out:
# model created sucessfully
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_1c (Conv1D)            (None, 13, 32)            128
# _________________________________________________________________
# layer_1m (MaxPooling1D)      (None, 7, 32)             0
# _________________________________________________________________
# layer_1bn (BatchNormalizatio (None, 7, 32)             128
# _________________________________________________________________
# layer_2c (Conv1D)            (None, 7, 32)             3104
# _________________________________________________________________
# layer_2m (MaxPooling1D)      (None, 4, 32)             0
# _________________________________________________________________
# layer_2bn (BatchNormalizatio (None, 4, 32)             128
# _________________________________________________________________
# layer_3c (Conv1D)            (None, 4, 32)             3104
# _________________________________________________________________
# layer_3m (MaxPooling1D)      (None, 2, 32)             0
# _________________________________________________________________
# layer_3bn (BatchNormalizatio (None, 2, 32)             128
# _________________________________________________________________
# layer_4c (Conv1D)            (None, 2, 32)             3104
# _________________________________________________________________
# layer_4m (MaxPooling1D)      (None, 1, 32)             0
# _________________________________________________________________
# layer_4bn (BatchNormalizatio (None, 1, 32)             128
# _________________________________________________________________
# layer_5c (Conv1D)            (None, 1, 32)             3104
# _________________________________________________________________
# layer_5m (MaxPooling1D)      (None, 1, 32)             0
# _________________________________________________________________
# layer_5bn (BatchNormalizatio (None, 1, 32)             128
# _________________________________________________________________
# layer_fl (Flatten)           (None, 32)                0
# _________________________________________________________________
# layer_d1 (Dense)             (None, 256)               8448
# _________________________________________________________________
# layer_d2 (Dense)             (None, 128)               32896
# _________________________________________________________________
# layer_d3 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 64)                0
# =================================================================
# Total params: 62,784
# Trainable params: 62,464
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# #Loading Weights from pre-trained model

# %%
Model_Emotion.load_weights('/content/drive/MyDrive/Speech_Emotion_Analysis_TL/weights/Accentweights.h5',by_name=True)

# %% [markdown]
# #Adding output Layer

# %%
#Model_Emotion.add(keras.layers.Dense(256,activation='relu',trainable=True))
#Model_Emotion.add(keras.layers.Dense(128,activation='relu',trainable=True))
#Model_Emotion.add(keras.layers.Dense(64,activation='relu',trainable=True))
Model_Emotion.add(keras.layers.Dense(6,activation='softmax',name="new_output"))

# %% [markdown]
# #Training Model

# %%
history_Model_Emotion = Model_Emotion.fit(model_Emotion_xtrain,model_Emotion_ytrain,validation_data=(model_Emotion_xvalid, model_Emotion_yvalid),verbose=1,epochs=150,batch_size=32)
# Out:
# Epoch 1/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.7518 - accuracy: 0.7114 - val_loss: 1.7195 - val_accuracy: 0.3819
# Epoch 2/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7599 - accuracy: 0.7106 - val_loss: 1.7518 - val_accuracy: 0.3586
# Epoch 3/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7742 - accuracy: 0.7230 - val_loss: 1.7932 - val_accuracy: 0.3703
# Epoch 4/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7896 - accuracy: 0.6880 - val_loss: 1.7568 - val_accuracy: 0.3819
# Epoch 5/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7432 - accuracy: 0.7252 - val_loss: 1.8082 - val_accuracy: 0.3848
# Epoch 6/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7685 - accuracy: 0.6990 - val_loss: 1.8008 - val_accuracy: 0.3673
# Epoch 7/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7442 - accuracy: 0.7252 - val_loss: 1.7523 - val_accuracy: 0.3878
# Epoch 8/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7598 - accuracy: 0.7150 - val_loss: 1.7499 - val_accuracy: 0.4140
# Epoch 9/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7629 - accuracy: 0.7208 - val_loss: 1.7571 - val_accuracy: 0.4023
# Epoch 10/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7239 - accuracy: 0.7223 - val_loss: 1.7958 - val_accuracy: 0.3761
# Epoch 11/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7369 - accuracy: 0.7128 - val_loss: 1.7202 - val_accuracy: 0.3907
# Epoch 12/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7593 - accuracy: 0.7136 - val_loss: 1.7526 - val_accuracy: 0.3673
# Epoch 13/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7110 - accuracy: 0.7413 - val_loss: 1.7631 - val_accuracy: 0.3936
# Epoch 14/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7521 - accuracy: 0.7106 - val_loss: 1.7131 - val_accuracy: 0.3936
# Epoch 15/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7146 - accuracy: 0.7230 - val_loss: 1.7634 - val_accuracy: 0.3732
# Epoch 16/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7408 - accuracy: 0.7128 - val_loss: 1.7817 - val_accuracy: 0.4023
# Epoch 17/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7508 - accuracy: 0.7143 - val_loss: 1.8101 - val_accuracy: 0.3644
# Epoch 18/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7282 - accuracy: 0.7208 - val_loss: 1.8014 - val_accuracy: 0.3703
# Epoch 19/150
# 43/43 [==============================] - 0s 6ms/step - loss: 0.7577 - accuracy: 0.7114 - val_loss: 1.8197 - val_accuracy: 0.3557
# Epoch 20/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.7370 - accuracy: 0.7136 - val_loss: 1.7989 - val_accuracy: 0.4023
# Epoch 21/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7042 - accuracy: 0.7332 - val_loss: 1.8536 - val_accuracy: 0.3615
# Epoch 22/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7196 - accuracy: 0.7420 - val_loss: 1.7508 - val_accuracy: 0.3907
# Epoch 23/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7403 - accuracy: 0.7106 - val_loss: 1.7506 - val_accuracy: 0.4169
# Epoch 24/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.7305 - accuracy: 0.7077 - val_loss: 1.7944 - val_accuracy: 0.3703
# Epoch 25/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.6836 - accuracy: 0.7449 - val_loss: 1.7889 - val_accuracy: 0.3819
# Epoch 26/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.6711 - accuracy: 0.7507 - val_loss: 1.8285 - val_accuracy: 0.3703
# Epoch 27/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.
150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5211 - accuracy: 0.8032 - val_loss: 2.0497 - val_accuracy: 0.3965
# Epoch 124/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4954 - accuracy: 0.8236 - val_loss: 2.1593 - val_accuracy: 0.3586
# Epoch 125/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5258 - accuracy: 0.8105 - val_loss: 2.1548 - val_accuracy: 0.3411
# Epoch 126/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4878 - accuracy: 0.8258 - val_loss: 2.2069 - val_accuracy: 0.3586
# Epoch 127/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.4924 - accuracy: 0.8171 - val_loss: 2.1371 - val_accuracy: 0.3848
# Epoch 128/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4755 - accuracy: 0.8316 - val_loss: 2.1412 - val_accuracy: 0.3761
# Epoch 129/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.5218 - accuracy: 0.8010 - val_loss: 2.0979 - val_accuracy: 0.4111
# Epoch 130/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.5064 - accuracy: 0.8098 - val_loss: 2.1377 - val_accuracy: 0.3819
# Epoch 131/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5104 - accuracy: 0.8120 - val_loss: 2.2581 - val_accuracy: 0.3440
# Epoch 132/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5114 - accuracy: 0.8134 - val_loss: 2.1342 - val_accuracy: 0.3528
# Epoch 133/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5105 - accuracy: 0.8141 - val_loss: 2.0919 - val_accuracy: 0.3848
# Epoch 134/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.4685 - accuracy: 0.8345 - val_loss: 2.0789 - val_accuracy: 0.3732
# Epoch 135/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5222 - accuracy: 0.8025 - val_loss: 2.1363 - val_accuracy: 0.3615
# Epoch 136/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5042 - accuracy: 0.8200 - val_loss: 2.1781 - val_accuracy: 0.3528
# Epoch 137/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4929 - accuracy: 0.8185 - val_loss: 2.2160 - val_accuracy: 0.3586
# Epoch 138/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4560 - accuracy: 0.8287 - val_loss: 2.2216 - val_accuracy: 0.3499
# Epoch 139/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.4946 - accuracy: 0.8214 - val_loss: 2.1457 - val_accuracy: 0.3732
# Epoch 140/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4769 - accuracy: 0.8273 - val_loss: 2.2021 - val_accuracy: 0.3907
# Epoch 141/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5157 - accuracy: 0.7988 - val_loss: 2.2175 - val_accuracy: 0.3615
# Epoch 142/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.5347 - accuracy: 0.8134 - val_loss: 2.1322 - val_accuracy: 0.3790
# Epoch 143/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4179 - accuracy: 0.8571 - val_loss: 2.1621 - val_accuracy: 0.3615
# Epoch 144/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4848 - accuracy: 0.8236 - val_loss: 2.3867 - val_accuracy: 0.3557
# Epoch 145/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4780 - accuracy: 0.8331 - val_loss: 2.2986 - val_accuracy: 0.3382
# Epoch 146/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4425 - accuracy: 0.8397 - val_loss: 2.2858 - val_accuracy: 0.3382
# Epoch 147/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.4551 - accuracy: 0.8418 - val_loss: 2.2409 - val_accuracy: 0.3499
# Epoch 148/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4195 - accuracy: 0.8499 - val_loss: 2.2900 - val_accuracy: 0.3557
# Epoch 149/150
# 43/43 [==============================] - 0s 8ms/step - loss: 0.4778 - accuracy: 0.8287 - val_loss: 2.2267 - val_accuracy: 0.3673
# Epoch 150/150
# 43/43 [==============================] - 0s 7ms/step - loss: 0.4554 - accuracy: 0.8258 - val_loss: 2.3342 - val_accuracy: 0.3528

# %% [markdown]
# #Testing and saving models

# %%
testModelAccuracy(Model_Emotion,model_Emotion_xtest,model_Emotion_ytest)
PlotAccuracy(history_Model_Emotion)

Model_Emotion.save("/content/drive/MyDrive/Speech_Emotion_Analysis_TL/savedModels/savedModelEmotion.h5")
# Out:
# Accuracy on test is: 0.811188817024231
#
# Error on test is: 0.648032009601593
